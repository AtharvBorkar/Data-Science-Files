# %%
import pandas as pd

# %%
pd.read_excel("data.xlsx")
# Out:
#      Name     School  Marks
# 0  Shubham       olx     34
# 1     Jack       bba     43
# 2     Alex       wps     24
# 3     Hary       aps     87
# 4   Bhadva  mcSchool     75
# 5   Akash         bc     98
# 6  Jasmine  mzSchool     12

# %%
df =  pd.read_json("data.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df =  pd.read_json("data.json")
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\json\_json.py:853, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     851     return json_reader
#     852 else:
# --> 853     return json_reader.read()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\json\_json.py:989, in JsonReader.read(self)
#     987         obj = self._read_pyarrow()
#     988     elif self.engine == "ujson":
# --> 989         obj = self._read_ujson()
#     991 return obj
#
# ...
