# %%
import pandas as pd

# %%
pd.read_excel("data.xlsx")
# Out:
#      Name     School  Marks
# 0  Shubham       olx     34
# 1     Jack       bba     43
# 2     Alex       wps     24
# 3     Hary       aps     87
# 4   Bhadva  mcSchool     75
# 5   Akash         bc     98
# 6  Jasmine  mzSchool     12

# %%
df =  pd.read_json("data.json")

# %%
df
# Out:
#      name  age      city
# 0  Shreya   25  New York
# 1  Shreya   90  Thailand
