# %%
import pandas as pd

# %%
s1 = pd.Series([72, 84, 56, 23, 56,])

# %%
type(s1)
# Out:
# pandas.Series

# %%
s2 = pd.Series([72, 84, 56, 23, 56,], index=['meow meow', 'atharva', 'shreya', 'anu', 'veda'])

# %%
s2
# Out:
# meow meow    72
# atharva      84
# shreya       56
# anu          23
# veda         56
# dtype: int64

# %%
s2['veda']
# Out:
# np.int64(56)
