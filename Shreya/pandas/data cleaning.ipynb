# %%
import pandas as pd
df = pd.read_csv("data_cleaning_sample.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 df = pd.readd_csv("data_cleaning_sample.csv")
#
# AttributeError: module 'pandas' has no attribute 'readd_csv'
