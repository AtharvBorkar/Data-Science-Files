# %%
import numpy as np

# %%
arr = np.array([23, 4, 3, 23])

# %%
arr.dtype
# Out:
# dtype('int64')

# %% [raw]
# arr.astype('float64')

# %%
arr2 = np.array([23, 4,3,23 ], dtype=("float32")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 arr2 = np.array([23, 4,3,23 ], dtype="float32")
#
# NameError: name 'np' is not defined
