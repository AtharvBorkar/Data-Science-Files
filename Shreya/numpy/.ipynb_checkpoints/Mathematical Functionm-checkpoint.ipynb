# %%
import numpy as np

# %%
arr = np.array([3, 5, 2, 33])

# %%
np.mean(arr)
# Out:
# np.float64(10.75)

# %%
np.min(arr)
# Out:
# np.int64(2)

# %%
np.max(arr)
# Out:
# np.int64(33)

# %%
np.prod(arr)
# Out:
# np.int64(990)

# %%
np.sum(arr)
# Out:
# np.int64(43)

# %%
np.unique(arr)

# %%
np.argmax(arr)
# Out:
# np.int64(3)

# %%
np.cumsum(arr)
# Out:
# array([ 3,  8, 10, 43])

# %%
aaaa
