# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5,])

# %%
result = []

# %%
for num in arr:

# %%
result.append(num ** 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 result.append(num ** 2)
#
# NameError: name 'num' is not defined

# %%
print(result)
# Out:
# []
