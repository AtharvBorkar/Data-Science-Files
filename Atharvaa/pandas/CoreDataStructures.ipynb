# %%
import pandas as pd

# %%
s = pd.Series([71, 84, 56, 90, 98, 56])

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
print(s)
# Out:
# 0    71
# 1    84
# 2    56
# 3    90
# 4    98
# 5    56
# dtype: int64
