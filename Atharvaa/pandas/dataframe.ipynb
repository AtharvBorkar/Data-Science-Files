# %%
import pandas as pd

# %%
data = [['harry', 34], ['jack', 67], ['jaccob', 67], ['shubham', 67]]

# %%
pd.DataFrame(data,columns=['Name', 'Age'])
# Out:
#       Name  Age
# 0    harry   34
# 1     jack   67
# 2   jaccob   67
# 3  shubham   67

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#          0   1
# 0    harry  34
# 1     jack  67
# 2   jaccob  67
# 3  shubham  67
