# %%
import pandas as pd

# %%
s1 = pd.Series([71, 84, 56, 90, 98, 56])

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
print(s1)
# Out:
# 0    71
# 1    84
# 2    56
# 3    90
# 4    98
# 5    56
# dtype: int64

# %%
s2 = pd.Series([71, 84, 56, 90, 98, 56], index=['Madarchli', 'Ghuse', 'Vairagade', 'Bangar', 'Shubh', 'Rohan'])

# %%
s2
# Out:
# Madarchli    71
# Ghuse        84
# Vairagade    56
# Bangar       90
# Shubh        98
# Rohan        56
# dtype: int64

# %%
s2["Bangar"]
# Out:
# np.int64(90)

# %%
s2["Rohan"]
# Out:
# np.int64(56)

# %%
s2["Shubh"]
# Out:
# np.int64(98)

# %%
data = {
    "name" : ["Atharvaa", "Rohan", "Shubh", "Bangar", "Vairagade", "Ghuse"],
    "marks" : [71, 84, 56, 90, 98, 56],
    "city" : ["Mumbai", "Delhi", "Bangalore", "Chennai", "Hyderabad", "Kolkata"]
}

# %%
pd.DataFrame(data)
# Out:
#         name  marks       city
# 0   Atharvaa     71     Mumbai
# 1      Rohan     84      Delhi
# 2      Shubh     56  Bangalore
# 3     Bangar     90    Chennai
# 4  Vairagade     98  Hyderabad
# 5      Ghuse     56    Kolkata

# %%
df = pd.DataFrame(data)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.columns
# Out:
# Index(['name', 'marks', 'city'], dtype='object')
