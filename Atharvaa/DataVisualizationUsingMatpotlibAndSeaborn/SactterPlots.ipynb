# %%
import matplotlib.pyplot as plt

# %%
study_hours = [1, 2, 3, 4, 5, 6, 7, 8, 9]
exam_scores = [40,45,50,55,60,65,70,75,80]

# %%
color = ['red' if score < 50 else 'green' for score in exam_scores]
plt.scatter(study_hours, exam_scores, c=color)
plt.grid(True)
plt.xlabel('Study Hours')
plt.ylabel('Exam Scores')
plt.title('Scatter Plot of Study Hours vs Exam Scores')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Study Hours vs Exam Scores')
