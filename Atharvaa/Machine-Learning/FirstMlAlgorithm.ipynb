# %%
from sklearn.tree import DecisionTreeClassifier

# %%
features = [[150, 0],
            [170, 0],
            [130, 1],
            [120, 1]
            ]

# %%
labels = ["apple", "apple", "orange", "orange"]
