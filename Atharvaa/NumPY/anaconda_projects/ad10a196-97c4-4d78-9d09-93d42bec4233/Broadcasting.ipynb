# %%
import numpy as np

# %%
arr = np.array([1, 2, 3, 4, 5])
result = arr ** 2 #Vectorizatio
print(result) #output
# Out:
# [ 1  4  9 16 25]

# %%
arr = np.array([1, 2, 3, 4, 5])
result = arr ** 4 #Vectorizatio
print(result) #output
# Out:
# [  1  16  81 256 625]
