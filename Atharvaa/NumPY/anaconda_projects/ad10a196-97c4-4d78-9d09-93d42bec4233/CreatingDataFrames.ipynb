# %%
import pandas as pd

# %%
data = [['Harry', 34], ["Jack", 30], ["Rohan", 16], ["Shubh", 20]]

# %%
data
# Out:
# [['Harry', 34], ['Jack', 30], ['Rohan', 16], ['Shubh', 20]]

# %%
pd.DataFrame(data)
# Out:
#        0   1
# 0  Harry  34
# 1   Jack  30
# 2  Rohan  16
# 3  Shubh  20

# %%
pd.DataFrame(data, columns=['Name', 'Age'])
# Out:
#     Name  Age
# 0  Harry   34
# 1   Jack   30
# 2  Rohan   16
# 3  Shubh   20

# %%
data = {'a': [1, 2, 3, 4], 'b': [5, 6, 7, 8]}

# %%
data
# Out:
# {'a': [1, 2, 3, 4], 'b': [5, 6, 7, 8]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    a  b
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
import numpy as np

# %%
arr = np.array([[1,2], [3,4], [5,6]])

# %%
df = pd.DataFrame(arr, columns=["A", "B"])

# %%
df
# Out:
#    A  B
# 0  1  2
# 1  3  4
# 2  5  6
